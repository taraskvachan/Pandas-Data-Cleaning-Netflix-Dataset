# %%
import pandas as pd

# %% [markdown]
# ## Task 1: Dataset Overview

# %%
df_netflix = pd.read_csv('Data/netflix_titles.csv')
df_netflix.sample(5)
# Out:
#        show_id     type                          title         director  \
# 2412  80097072  TV Show  NATURE: Natural Born Hustlers              NaN
# 3055  81121179    Movie   NOVA: Extreme Animal Weapons      Peter Fison
# 1706  80080768    Movie       The Blackcoat's Daughter   Osgood Perkins
# 321   70058023    Movie                       Superbad     Greg Mottola
# 1120  80125671    Movie                    Shot Caller  Ric Roman Waugh
#
#                                                    cast  \
# 2412                                       Kevin Draine
# 3055                                       Doug Averill
# 1706  Emma Roberts, Kiernan Shipka, Lucy Boynton, La...
# 321   Jonah Hill, Michael Cera, Christopher Mintz-Pl...
# 1120  Nikolaj Coster-Waldau, Omari Hardwick, Lake Be...
#
#                     country         date_added  release_year rating  duration  \
# 2412          United States      March 1, 2017          2016   TV-G  1 Season
# 3055          United States       July 1, 2019          2017  TV-PG    53 min
# 1706  Canada, United States       May 18, 2019          2015      R    95 min
# 321           United States  September 1, 2019          2007      R   113 min
# 1120          United States  November 24, 2019          2017      R   121 min
#
#                                          listed_in  \
# 2412               Docuseries, Science & Nature TV
# 3055                                 Documentaries
# 1706  Horror Movies, Independent Movies, Thrillers
# 321                          Comedies, Cult Movies
# 1120                             Dramas, Thrillers
#
#                                             description
# 2412  Sometimes being shady is the only way to survi...
# 3055  From huge tusks to giant horns, some animals s...
# 1706  When their parents fail to pick them up for wi...
# 321   Two best friends' quest to buy booze for a par...
# 1120  Trying to go straight, a once-successful busin...

# %%
df_netflix.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_netflix.shape
# Out:
# (6234, 12)

# %% [markdown]
# ## Task 2: Identifying missing data

# %%
# Number of rows missing in each column
df_netflix.isnull().sum().sort_values(ascending = False)
# Out:
# director        1969
# cast             570
# country          476
# date_added        11
# rating            10
# show_id            0
# type               0
# title              0
# release_year       0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# % of rows missing in each column
df_netflix.isnull().mean().round(4).sort_values(ascending = False) * 100
# Out:
# director        31.58
# cast             9.14
# country          7.64
# date_added       0.18
# rating           0.16
# show_id          0.00
# type             0.00
# title            0.00
# release_year     0.00
# duration         0.00
# listed_in        0.00
# description      0.00
# dtype: float64

# %% [markdown]
# ## Task 3: Dealing with missing data

# %%
# Drop 'director' column
# df_netflix.drop('director', axis = 1)

# %%
# Drop row
# no_director = df_netflix[df_netflix['director'].isnull()].index
# df_netflix.drop(no_director, axis = 0)

# %%
df_netflix.drop(no_director, axis = 0).isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            356
# country         171
# date_added        0
# release_year      0
# rating            6
# duration          0
# listed_in         0
# description       0
# dtype: int64

#
International TV Shows, Romantic TV Shows, TV ...
#
#                                             description
# 0     Before planning an awesome wedding for his gra...
# 4     When nerdy high schooler Dani finally attracts...
# 6     In a dystopian future, an insurance adjuster f...
# 7     Fabrizio Copano takes audience participation t...
# 9     A struggling couple can't believe their luck w...
# ...                                                 ...
# 6142  A talented batch of amateur bakers face off in...
# 6158  When Paris is in peril, Marinette becomes Lady...
# 6167  A link in their pasts leads an honest cop to a...
# 6182  Male celebs play make-believe as high schooler...
# 6213  Destiny brings Mecnun and Leyla together as ne...
#
# [4265 rows x 12 columns]

# %%
# Use fillan() to replace NAN by the mean, median or mode

df_netflix['rating'].mode()
# Out:
# 0    TV-MA
# Name: rating, dtype: object

# %%
mode = ''.join(df_netflix['rating'].mode())

# %%
df_netflix['rating'] = df_netflix['rating'].fillna(mode)

# %%
df_netflix.sample(5)
# Out:
#        show_id     type                  title     director  \
# 3409  80156940    Movie         Pyar Ke Do Pal  Rajiv Mehra
# 5644  80109399  TV Show        Kibaoh Klashers          NaN
# 4248  81020868  TV Show  Conan Without Borders          NaN
# 1572  81104372  TV Show               What If?          NaN
# 3347  81038583  TV Show             Strongland          NaN
#
#                                                    cast        country  \
# 3409  Mithun Chakraborty, Jayapradha, Simple Kapadia...          India
# 5644  Ben Diskin, Cherami Leigh, Dakota Basseri, Kei...          China
# 4248                                                NaN  United States
# 1572  Monther Rayahnah, Khaled Ameen, Aseel Omran, R...            NaN
# 3347                                                NaN            NaN
#
#              date_added  release_year rating   duration  \
# 3409   January 15, 2018          1986  TV-PG    153 min
# 5644    October 6, 2017          2017  TV-Y7  2 Seasons
# 4248  December 31, 2018          2018  TV-14   1 Season
# 1572        May 7, 2019          2019  TV-14   1 Season
# 3347   January 18, 2019          2018  TV-PG   1 Season
#
#                                            listed_in  \
# 3409  Dramas, International Movies, Music & Musicals
# 5644                                        Kids' TV
# 4248                         Docuseries, TV Comedies
# 1572               International TV Shows, TV Dramas
# 3347              Docuseries, International TV Shows
#
#                                             description
# 3409  Twins separated by a court order meet at camp ...
# 5644  Young beetle Dylan and his friends Hailey and ...
# 4248  Late-night talk show host Conan O'Brien hits t...
# 1572  Four individuals at a crossroads in life are g...
# 3347  From Spain's countryside to Scotland's stony t...

# %%
df_netflix.drop(no_director, axis = 0).isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            356
# country         171
# date_added        0
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %% [markdown]
# ## Task 3: Extracting Data

# %%
df_movie = df_netflix[df_netflix['type'] == 'Movie']
df_movie['duration (min)'] = df_movie['duration'].str.split(expand = True)[0].astype(int)
# Out:
# /tmp/ipykernel_554/4042382993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie['duration (min)'] = df_movie['duration'].str.split(expand = True)[0].astype(int)

# %%
df_movie.sample(4)
# Out:
#        show_id   type                      title         director  \
# 4607  81035888  Movie        Good and Prosperous  Sameh Abdulaziz
# 87    80200087  Movie                     Domino   Brian De Palma
# 325   70136074  Movie          The Last Exorcism     Daniel Stamm
# 731   70280748  Movie  Russell Peters: Notorious       Dave Higby
#
#                                                    cast  \
# 4607  Ali Rabee, Mohamed Abdel-Rahman, Bayoumi Fouad...
# 87    Nikolaj Coster-Waldau, Carice van Houten, Eriq...
# 325   Patrick Fabian, Ashley Bell, Iris Bahr, Louis ...
# 731                                      Russell Peters
#
#                                            country          date_added  \
# 4607                                         Egypt   December 10, 2019
# 87    Denmark, France, Italy, Belgium, Netherlands  September 28, 2019
# 325                          France, United States   September 1, 2019
# 731                                  United States    October 14, 2013
#
#       release_year rating duration  \
# 4607          2017  TV-14  101 min
# 87            2019      R   89 min
# 325           2010  PG-13   88 min
# 731           2013     NR   72 min
#
#                                          listed_in  \
# 4607                Comedies, International Movies
# 87                 International Movies, Thrillers
# 325   Horror Movies, Independent Movies, Thrillers
# 731                                Stand-Up Comedy
#
#                                             description  duration (min)
# 4607  As two jobless brothers search aimlessly for c...             101
# 87    A Copenhagen police officer hunts for the man ...              89
# 325   Ready to expose his miraculous deeds as mere t...              88
# 731   Global comedy star Russell Peters leaves no et...              72

# %%
df_movie.dtypes
# Out:
# show_id            int64
# type              object
# title             object
# director          object
# cast              object
# country           object
# date_added        object
# release_year       int64
# rating            object
# duration          object
# listed_in         object
# description       object
# duration (min)     int64
# dtype: object

# %%
df_movie['year added'] = df_movie['date_added'].str.split(',', expand = True)[1]
# Out:
# /tmp/ipykernel_554/4243048977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie['year added'] = df_movie['date_added'].str.split(',', expand = True)[1]

# %%
df_movie.sample(4)
# Out:
#        show_id   type                              title        director  \
# 4919  70219529  Movie                              Joker  Shirish Kunder
# 5320  80003150  Movie  Secrets of Althorp - The Spencers  Kasia Uscinska
# 907   70229048  Movie                         Thaandavam           Vijay
# 2820  70250364  Movie       Katt Williams: Kattpacalypse    Marcus Raboy
#
#                                                    cast        country  \
# 4919  Akshay Kumar, Sonakshi Sinha, Shreyas Talpade,...          India
# 5320                                        Samuel West  United States
# 907   Vikram, Jagapathi Babu, Anushka Shetty, Amy Ja...          India
# 2820                                      Katt Williams  United States
#
#            date_added  release_year rating duration  \
# 4919   August 2, 2018          2012  TV-PG   98 min
# 5320   April 22, 2017          2013  TV-PG   54 min
# 907   October 1, 2018          2012  TV-14  156 min
# 2820     July 3, 2018          2012     NR   61 min
#
#                                               listed_in  \
# 4919   Comedies, International Movies, Music & Musicals
# 5320                Documentaries, International Movies
# 907   Action & Adventure, International Movies, Musi...
# 2820                                    Stand-Up Comedy
#
#                                             description  duration (min)  \
# 4919  A remote village situated neither in India or ...              98
# 5320  Princess Diana's brother, Charles, the ninth E...              54
# 907   In London, a mysterious blind man named Kenny ...             156
# 2820  Urban comic Katt Williams ushers in Kattpacaly...              61
#
#      year added
# 4919       2018
# 5320       2017
# 907        2018
# 2820       2018
